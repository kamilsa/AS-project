# %%
import numpy as np
from numpy import pi, r_
import matplotlib.pyplot as plt
from scipy import optimize
import pandas as pd

# Generate data points with noise
num_points = 150
Tx = np.linspace(5., 8., num_points)
Ty = Tx

tX = 11.86*np.cos(2*pi/0.81*Tx-1.32) + 0.64*Tx+4*((0.5-np.random.rand(num_points))*np.exp(2*np.random.rand(num_points)**2))
tY = -32.14*np.cos(2*np.pi/0.8*Ty-1.94) + 0.15*Ty+7*((0.5-np.random.rand(num_points))*np.exp(2*np.random.rand(num_points)**2))

# %%
# Fit the first set
fitfunc = lambda p, x: p[0]*np.cos(2*np.pi/p[1]*x+p[2]) + p[3]*x # Target function
errfunc = lambda p, x, y: fitfunc(p, x) - y # Distance to the target function
p0 = [-15., 0.8, 0., -1.] # Initial guess for the parameters
p1, success = optimize.leastsq(errfunc, p0[:], args=(Tx, tX))

time = np.linspace(Tx.min(), Tx.max(), 100)
plt.plot(Tx, tX, "ro", time, fitfunc(p1, time), "r-") # Plot of the data and the fit

# Fit the second set
p0 = [-15., 0.8, 0., -1.]
p2,success = optimize.leastsq(errfunc, p0[:], args=(Ty, tY))

time = np.linspace(Ty.min(), Ty.max(), 100)
plt.plot(Ty, tY, "b^", time, fitfunc(p2, time), "b-")

# Legend the plot
plt.title("Oscillations in the compressed trap")
plt.xlabel("time [ms]")
plt.ylabel("displacement [um]")
plt.legend(('x position', 'x fit', 'y position', 'y fit'))

ax = plt.axes()

plt.text(0.8, 0.07,
         'x freq :  %.3f kHz \n y freq :  %.3f kHz' % (1/p1[1],1/p2[1]),
         fontsize=16,
         horizontalalignment='center',
         verticalalignment='center',
         transform=ax.transAxes)

plt.show()

# %%
# Generate data points with noise
tizen = pd.read_csv("bugs-1-tizen.csv", delimiter=';')
num_points = 150
Tx = tizen.x.values

tX = tizen.y.values

# %%
# Fit the first set
# fitfunc = lambda p, x: p[0]*np.cos(2*np.pi/p[1]*x+p[2]) + p[3]*x # Target function
fitfunc = lambda p, x: p[0]*(1 - (1 + p[1]*x) * np.exp(-p[1]*x)) # G-O s shaped
# fitfunc = Weibull_S_Shaped
errfunc = lambda p, x, y: fitfunc(p, x) - y # Distance to the target function
p0 = [2000, 0.1,] # Initial guess for the parameters
p1, success = optimize.leastsq(errfunc, p0[:], args=(Tx, tX))
# noized_tizen = noize_bags(tizen,std = 1000)
# p1, success = optimize.leastsq(errfunc, p0[:], args=(noized_tizen.x.values, noized_tizen.y.values))
time = np.linspace(Tx.min(), Tx.max(), 100)
plt.plot(Tx, tX, "r--", time, fitfunc(p1, time), "r-") # Plot of the data and the fit
# plt.plot(noized_tizen.x.values, noized_tizen.y.values, "r--", time, fitfunc(p1, time), "r-") # Plot of the data and the fit

# Legend the plot
plt.title("Oscillations in the compressed trap")
plt.xlabel("time [ms]")
plt.ylabel("displacement [um]")
plt.legend(('x position', 'x fit', 'y position', 'y fit'))

ax = plt.axes()

plt.text(0.8, 0.07,
         'x freq :  %.3f kHz \n y freq :  %.3f kHz' % (1/p1[1],1/p2[1]),
         fontsize=16,
         horizontalalignment='center',
         verticalalignment='center',
         transform=ax.transAxes)

plt.show()

# %%
p1, success
# Out:
# (array([  8.54115947e+03,   1.85852351e-03]), 1)

# %%
def noize_bags(df, mean=0, std=1):
    vals = df['y'].values
    num_errors = np.zeros(len(vals),dtype=int)
    for i in range(len(vals))[:0:-1]:
        num_errors[i] = vals[i] - vals[i-1]
    arr = list(map(lambda x: np.ones(x), num_errors))
    noized = [[] for x in range(len(arr))]
    for i in range(len(arr)):
        for j in arr[i]:
            dif = int(np.random.normal(mean, std,1)[0])
            if (i+dif >0 and i+dif < len(noized)-1):
                noized[i+dif].append(1)
    noized_days = np.array(list(map(lambda x: len(x), noized)))
    cdf = np.zeros(len(noized_days), dtype=int)
    for i in range(len(cdf)):
        if i == 0:
            cdf[i] = noized_days[i]
        else:
            cdf[i] = cdf[i-1] + noized_days[i]
    res = pd.DataFrame(columns=['x','y'])
    res.x = df.x
    res.y = cdf
    return res

def GoF(y_predicted, y, param_number):
    """
    Goodness of Fit shows how well the model fits the original data. 
    GoF is calculated as a sum of squared residuals divided by the number of degrees of freedom
    
    :param y_predicted: NumPy array of predicted values
    :param y: NumPy array of actual values
    :param param_number: number of model parametres. Used to estimate degrees of freedom.
    :return: float number
    """
    return np.sum(np.power(y_predicted - y, 2)) / (len(y) - param_number)

def PA(trainset, fit_func, x_label='x', y_label='y', errfunc = lambda p, x, y: fitfunc(p, x) - y, p0 = [2000, 0.1]):
    """
    Predictive Ability shows how early in the testing 
    the model is able to predict the final number 
    of defects with maximum 10% error. Measured in percentages.
    """
#     last = len(trainset)
#     for i in range(1, last-1):
#         tr = trainset.head(last - i)
# #         popt, pcov = curve_fit(fit_func, tr[x_label].values, tr[y_label].values)
#         errfunc = lambda p, x, y: fitfunc(p, x) - y # Distance to the target function
#         p1, success = optimize.leastsq(errfunc, p0[:], args=(tr[x_label].values, tr[y_label].values))
#         a = p1[0]
#         error = AcFP(trainset.y.iloc[-1], a)
#         if error > 10:
#             pa = round(float(1 - (i-1))/last, 6)
#             break
#     return pa*100
    X = trainset.x
    y = trainset.y
    last = len(trainset)
    for i in range(1, last-1):
        tr = trainset.head(last - i)
        errfunc = lambda p, x, y: fitfunc(p, x) - y # Distance to the target function
        p1, success = optimize.leastsq(errfunc, p0[:], args=(tr.x.values, tr.y.values))
        predicted = fitfunc(p1, last - 1)
        error = AcFP(y[last-1], predicted)
        if error > 10:
            pa = round(float(i)/last, 6)
            break
    return pa*100
        
def AcFP(real, predicted):
    """
    The accuracy of final point (AcFP) corresponds to the effectiveness of the model 
    in determining the final number of defects observed in the dataset.
    """
    return np.abs(real - predicted) / real * 100

# %%
PA(tizen, fitfunc)
# Out:
# 3.6172000000000004

# %%
def experiment(tizen, std, fitfunc):
    gof_err = 0
    pa_err = 0
    noized_tizen = noize_bags(tizen,std = std)
    #         srgm = SoftwareReliabilityGrowthModel(Goel_Okumoto_S_Shaped)
    #         srgm.fit(noized_tizen.x.values, noized_tizen.y.values)
    p0 = [2000, 0.1,] # Initial guess for the parameters
    p1, success = optimize.leastsq(errfunc, p0[:], args=(noized_tizen.x.values, noized_tizen.y.values))
    y_pred = fitfunc(p1, noized_tizen.x)
    mse = GoF(tizen.y.values, y_pred,len(p0))
    pa = PA(noized_tizen, fitfunc)
    if float(abs(mse - mse_baseline))/mse_baseline > 0.05:
        gof_err += 1
    if float(abs(pa - pa_baseline))/pa_baseline > 0.05:
        pa_err += 1
    return mse, pa, gof_err, pa_err

# %%
# %%time
## Goel_Okumoto_S_Shaped test

fitfunc = lambda p, x: p[0]*(1 - (1 + p[1]*x) * np.exp(-p[1]*x))
errfunc = lambda p, x, y: fitfunc(p, x) - y # Distance to the target function
p0 = [2000, 0.1,] # Initial guess for the parameters
p1, success = optimize.leastsq(errfunc, p0[:], args=(Tx, tX))

y_pred = fitfunc(p1, tizen.x)
mse_baseline = GoF(y_pred, tizen.y.values,len(p0))
pa_baseline = PA(tizen, fitfunc)
print(mse_baseline, pa_baseline)

mmses = []
mpases = []
gof_errors = []
pa_errors = []

counter = 0
std = 1
# for std in range(10,101,10):
while True:
    counter += 1
    std += 1
    print("std = ", std)
    exps = 3 # number of experiments (should be 1000)
    mses = []
    pas = []
    gof_err = 0
    pa_err = 0
#     with ThreadPoolExecutor(max_workers=1) as executor:
    for i in range(exps):
#         noized_tizen = noize_bags(tizen,std = std)
# #         srgm = SoftwareReliabilityGrowthModel(Goel_Okumoto_S_Shaped)
# #         srgm.fit(noized_tizen.x.values, noized_tizen.y.values)
#         p0 = [2000, 0.1,] # Initial guess for the parameters
#         p1, success = optimize.leastsq(errfunc, p0[:], args=(noized_tizen.x.values, noized_tizen.y.values))
#         y_pred = fitfunc(p1, noized_tizen.x)
#         mse = GoF(tizen.y.values, y_pred,len(p0))
#         pa = PA(noized_tizen, fitfunc)
#         if float(abs(mse - mse_baseline))/mse_baseline > 0.05:
#             gof_err += 1
            
#         if float(abs(pa - pa_baseline))/pa_baseline > 0.05:
#             pa_err += 1
        mse, pa, gof_err, pa_err = experiment(tizen, std, fitfunc)
        mses.append(mse)
        pas.append(pa)
    mmse = np.mean(np.array(mses))
    mpas = np.mean(np.array(pas))
    
    mmses.append(mmse)
    mpases.append(mpas)
    gof_errors.append(gof_err)
    pa_errors.append(pa_err)
    
    print("%f of gof errors" % (float(gof_err)*100/exps))
    print("%f of pa errors" % (float(pa_err)*100/exps))
    if float(gof_err)/exps > 0.05 and float(pa_err)/exps > 0.05:
        break
print("Done")
# Out:
# 80615.7671272 3.6172000000000004
# std =  2
# 0.000000 of gof errors
# 0.000000 of pa errors
# std =  3
# 0.000000 of gof errors
# 0.000000 of pa errors
# std =  4
# 0.000000 of gof errors
# 0.000000 of pa errors
# std =  5
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  6
# 0.000000 of gof errors
# 0.000000 of pa errors
# std =  7
# 0.000000 of gof errors
# 0.000000 of pa errors
# std =  8
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  9
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  10
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  11
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  12
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  13
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  14
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  15
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  16
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  17
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  18
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  19
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  20
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  21
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  22
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  23
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  24
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  25
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  26
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  27
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  28
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  29
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  30
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  31
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  32
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  33
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  34
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  35
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  36
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  37
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  38
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  39
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  40
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  41
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  42
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  43
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  44
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  45
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  46
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  47
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  48
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  49
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  50
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  51
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  52
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  53
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  54
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  55
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  56
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  57
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  58
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  59
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  60
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  61
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  62
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  63
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  64
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  65
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  66
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  67
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  68
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  69
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  70
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  71
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  72
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  73
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  74
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  75
# 0.000000 of gof errors
# 33.333333 of pa errors
# std =  76
# 33.333333 of gof errors
# 33.333333 of pa errors
# Done
# CPU times: user 31.9 s, sys: 48 ms, total: 32 s
# Wall time: 31.9 s

# %%
df = pd.DataFrame(columns=['std', 'mmse', 'mpa','gof_errs', 'pa_errs'])
df['std'] = np.array(list(range(1, std)))
df['mmse'] = np.array(mmses)
df['mpa'] = np.array(mpases)
df.gof_errs = np.array(gof_errors)
df.pa_errs = np.array(pa_errors)
df
# Out:
#     std          mmse       mpa  gof_errs  pa_errs
# 0     1  80616.265968  3.541808         0        0
# 1     2  80616.819486  3.528255         0        0
# 2     3  80617.154927  3.504902         0        4
# 3     4  80617.904164  3.486818         0       15
# 4     5  80619.343505  3.461201         0       23
# 5     6  80619.289462  3.432557         0       52
# 6     7  80620.413488  3.401650         0       66
# 7     8  80620.518653  3.385823         0       73
# 8     9  80621.356228  3.349647         0       85
# 9    10  80624.066226  3.327791         0       87
# 10   11  80623.544068  3.299909         0       91
# 11   12  80625.420533  3.262226         0       99
# 12   13  80629.272299  3.245647         0       98
# 13   14  80629.544691  3.227566         0      100
# 14   15  80631.175733  3.183103         0      100
# 15   16  80632.825324  3.183862         0       99
# 16   17  80637.060945  3.158241         0       98
# 17   18  80637.786600  3.100220         0      100
# 18   19  80645.367100  3.094947         0       99
# 19   20  80642.934397  3.094197         0       99
# 20   21  80652.171242  3.048228         0      100
# 21   22  80657.602396  3.049740         0      100
# 22   23  80668.530275  3.017334         0      100
# 23   24  80680.136691  2.964586         0      100
# 24   25  80683.387727  2.954787         0      100
# 25   26  80712.455662  2.908815         0      100
# 26   27  80731.159073  2.888469         0      100
# 27   28  80749.871357  2.896761         0      100
# 28   29  80755.660933  2.861337         0      100
# 29   30  80802.277909  2.815370         0      100
# ..  ...           ...       ...       ...      ...
# 35   36  80993.156120  2.702337         0      100
# 36   37  81057.616463  2.654859         0      100
# 37   38  81114.625492  2.661637         0      100
# 38   39  81174.088023  2.633006         0      100
# 39   40  81242.126751  2.560669         0      100
# 40   41  81271.657939  2.581013         0      100
# 41   42  81337.925366  2.559160         0      100
# 42   43  81405.986254  2.549364         0      100
# 43   44  81535.052222  2.539569         0      100
# 44   45  81517.874922  2.535796         0      100
# 45   46  81590.189263  2.517715         0      100
# 46   47  81670.248011  2.474006         0      100
# 47   48  81804.302004  2.468727         0      100
# 48   49  81837.466795  2.455168         0      100
# 49   50  81918.797754  2.446125         0      100
# 50   51  81922.042604  2.440101         0      100
# 51   52  82069.032802  2.419743         0      100
# 52   53  82189.004527  2.396385         0      100
# 53   54  82266.613668  2.404674         0      100
# 54   55  82391.939091  2.403169         0      100
# 55   56  82496.029957  2.388095         1      100
# 56   57  82545.037055  2.363982         0      100
# 57   58  82681.526561  2.371514         0      100
# 58   59  82747.681013  2.366995         1      100
# 59   60  83009.145080  2.332329         0      100
# 60   61  82949.880854  2.374526         1      100
# 61   62  83109.848450  2.391864         0      100
# 62   63  83266.162897  2.320277         4      100
# 63   64  83290.555476  2.376039         2      100
# 64   65  83457.612947  2.366245         7      100
#
# [65 rows x 5 columns]

# %%
df.to_csv('tizen-processed.csv',index=False)

# %%
def wait_on_b():
    time.sleep(5)
#     print(b.result())  # b will never complete because it is waiting on a.
    return 5

def wait_on_a():
    time.sleep(5)
#     print(a.result())  # a will never complete because it is waiting on b.
    return 6
with ThreadPoolExecutor(max_workers=2) as executor:
    a = executor.submit(wait_on_b)
    b = executor.submit(wait_on_a)
    print(a.result())
    print(b.result())
# Out:
# 5
# 6

# %%
a.result
# Out:
# <bound method Future.result of <Future at 0x7f1f2cd18e48 state=running>>
